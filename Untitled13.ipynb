# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
jk=pd.read_csv(r"C:\Users\ABIL SHAD\Downloads\incomeData.csv")

# %%
jk
# Out:
#        nan          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
jk.isnull().sum()
# Out:
# nan               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# Income            0
# dtype: int64

# %%
jk.describe()
# Out:
#                 nan        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
jk.head()
# Out:
#    nan          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  Income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
jk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   nan             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  Income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
jk.duplicated().sum()
# Out:
# 24

# %%
jk.columns
# Out:
# Index(['nan', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'Income'],
#       dtype='object')

# %%
jk["sex"].value_counts()
# Out:
# sex
# Male      21790
# Female    10771
# Name: count, dtype: int64

# %%
kk=jk.groupby("workclass")["Income"].value_counts()

# %%
kk
# Out:
# workclass         Income
# ?                 <=50K      1645
#                   >50K        191
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17733
#                   >50K       4963
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1817
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Without-pay       <=50K        14
# Name: count, dtype: int64

# %%
workclass_by_sex=kk.head(50)

# %%
workclass_by_sex
# Out:
# workclass         Income
# ?                 <=50K      1645
#                   >50K        191
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17733
#                   >50K       4963
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1817
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Without-pay       <=50K        14
# Name: count, dtype: int64

# %%
plt.figure(figsize=(25,35))
workclass_by_sex.plot(kind="pie",autopct='%1.1f%%', startangle=90, cmap='Set3')
plt.title('work class by income')
plt.ylabel("pie chart")
plt.legend(title="salary by job sector")
plt.show()

# %% [markdown]
# ### here we can find private sectors are providing <=50k/>=50k more compare to others

# %%
jk.head()
# Out:
#    nan          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  Income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
jk["race"].value_counts()
# Out:
# race
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64

# %%
jk["native-country"].value_counts()
# Out:
# native-country
# United-States                 29170
# Mexico                          643
# ?                               583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# ...

# %%
plt.figure(figsize=(10,6))
sns.histplot(jk["marital-status"],kde=True,alpha= 0.3,bins= 10,edgecolor= "black")

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### most of the employee is married-civ-spouse

# %%
jk.groupby("sex")["hours-per-week"].value_counts()
# Out:
# sex     hours-per-week
# Female  40                4922
#         35                 656
#         20                 644
#         30                 530
#         50                 465
#                           ...
# Male    73                   1
#         74                   1
#         87                   1
#         92                   1
#         94                   1
# Name: count, Length: 171, dtype: int64

# %%
plt.figure(figsize=(12, 5))
sns.countplot(data=jk, x='sex', hue='hours-per-week'==50, order=jk['sex'].value_counts().index, palette='Set2')
plt.title('sex vs hours per week')
plt.xlabel('sex')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### male workers are working more hours than female workers

# %%
low_income=jk[jk['Income'] == ' <=50K']

# %%
low_income
# Out:
#        nan          workclass  fnlwgt      education  education-num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       28            Private  338409      Bachelors             13
# ...    ...                ...     ...            ...            ...
# 32553   32            Private  116138        Masters             14
# 32555   22            Private  310152   Some-college             10
# 32556   27            Private  257302     Assoc-acdm             12
# 32558   58            Private  151910        HS-grad              9
# 32559   22            Private  201490        HS-grad              9
#
#             marital-status          occupation    relationship  \
# 0            Never-married        Adm-clerical   Not-in-family
# ...

# %%
high_income=jk[jk['Income']==" >50K"]

# %%
high_income
# Out:
#        nan          workclass  fnlwgt      education  education-num  \
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# 8       31            Private   45781        Masters             14
# 9       42            Private  159449      Bachelors             13
# 10      37            Private  280464   Some-college             10
# 11      30          State-gov  141297      Bachelors             13
# ...    ...                ...     ...            ...            ...
# 32539   71                  ?  287372      Doctorate             16
# 32545   39          Local-gov  111499     Assoc-acdm             12
# 32554   53            Private  321865        Masters             14
# 32557   40            Private  154374        HS-grad              9
# 32560   52       Self-emp-inc  287927        HS-grad              9
#
#             marital-status          occupation    relationship  \
# 7       Married-civ-spouse     Exec-managerial         Husband
# ...

# %%
sns.countplot(x=low_income['education'],palette='pastel')
plt.xticks(rotation=90)
plt.title("education  of low income individuals") 
plt.show()
# Out:
# C:\Users\ABIL SHAD\AppData\Local\Temp\ipykernel_5732\1029206924.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=low_income['education'],palette='pastel')

# %%
sns.countplot(x=high_income['education'],palette='pastel')
plt.xticks(rotation=90)
plt.title("education  of high income individuals") 
plt.show()
# Out:
# C:\Users\ABIL SHAD\AppData\Local\Temp\ipykernel_5732\3867689498.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=high_income['education'],palette='pastel')

# %% [markdown]
# ### education of employees influences the income of individuals

# %% [markdown]
# ### conclutions
# * private sectors are providing <=50k/>=50k more compare to others
# * most of the employee is married-civ-spouse
# * male workers are working more hours than female workers
# * education of employees influences the income of individuals
# * More hours doesn't guarantee higher income, but many high earners do work longer hours.
